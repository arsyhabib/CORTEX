# %% [markdown]
# # CORTEX Pipeline on Google Colab Pro
#
# Upload PDF ke Google Drive > My Drive > CORTEX > input/, lalu Run All.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
key = input('Google AI API Key: ') or os.environ.get('GOOGLE_AI_API_KEY','')
# !bash /content/drive/MyDrive/CORTEX/pipeline/cortex-colab-pipeline.sh "$key"
